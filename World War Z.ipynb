# %% [markdown]
# Khoa Le - A1: Text Adventure Game Development - World War Z
#
# 1) Introduction: This text adventure game is inspired by the movie of the same name - produced in 2013. The game's main content is to save the world from the zombie epidemic raging in the world. Players will have three countries to discover, and the maximum time is 3 minutes. You have to make the right decisions to have a chance to save the world. Let's play games!
#
#
# 2) Tips: In the final round, you need to break the code to call for reinforcements, who will accompany you to complete the final journey. Pay attention to that code and answer correctly in Australia round!
#
# Enjoy the game!
#
# Source: https://www.imdb.com/title/tt0816711/

# %%
## #MBAN 2 - Hult International Business School 
#Created by Khoa Le on 10.24.2021
#Assignment - A1: Text Adventure Game Development - World War Z
################################################################

# Applying the argument < prompt > to get player name 
player_name = input(prompt  = "What's your name? ")
print() 

# Capitalize player name 
player_name = player_name.capitalize()


# Welcome to Japan
print(f"""
            Hi {player_name}, welcome to Japan! You need to answer the 
            following question correctly to pass this room.""")

print()
input(prompt = 'Press any key to continue\n')

# Welcome to Narita International Airport 
def room_jp(): 
    print(f"""
            You have arrived at Narita International Airport!\n""")
    input(prompt = '<Press enter to continue>\n')
    
    print("Press 1 to go to exit the airport.")
    print("Press 2 to stay inside the airport.")
    
    choice = input(prompt = "(1/2)> ")    
       
    
# Developing a conditional statement 
    if choice == '1':
        print(f"""
            Then you must answer the random question 
            before entering the country.\n""")
    # Import random packages
        import random
        
    # Creating a question list that will be randomly selected
        from random import choice 
        question_listJPN = [
            """"\n
                  What is the capital of capital of Japan? 
                  A) Tokyo
                  B) Kyoto """,
            """"\n
                  What is the traditional clothes of Japan?
                  A) Kimono
                  B) Cheongsam """,
             """\n
                  What is the most traditional of Japan?
                  A) Sushi
                  B) Tacos    """]

        # Printing a question list 
        print(choice(question_listJPN))
        
        
        # Prompting to get input from the player
        answer = input(prompt = "(A/B)> ")
                       
                       
                       
        # Using .casefold() to lowercase
        answer = answer.casefold()
        
        # Start of nested conditional for random question Japan
        if answer in ('a', 'A'):
            print(f"""That's correct! Please enjoy Japan and let's prepare 
                      for the next challenges.""")
            input(prompt = 'Press any key continue>\n')
            room_astl()
            
        elif answer in ('b', 'B'):
            print(f"""You made a wrong choice, let's try again.\n""")
            input(prompt = 'Press any key to continue>\n')
            room_jp()
               
        else:
            print("That's incorrect.")
            fail()
            
            
        # End of nested conditional        
    elif choice == '2':
        fail()
    # If the player fails in this room, they are prompted to jp_room () for 
    
    # Passcode decoding. 
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        room_jp()
  # Closing if function 


# Welcome to Australia 
def room_astl():
    print(f"""
            Now you're in Australia. You have a chance to pick up 
            some weapons and ammunition. 
            You will need to answer Pick or Ignore. """)
            
        
    # Import random packages
    import random
    
    # Creating a quesion list that will be randomly selected 
    from random import choice
    
    question_listAUS = ["""\n
            On the way to the zoombies' killing site,
            you find a MA41 gun and ammo, which can help you kill 
            zoombies faster.
            Should you pick it or ignore it? """,
            """\n
            You are lucky to find a machine gun and 3 grenades. 
            Let's pick it up to kill the zombies. 
            Should you pick it or ignore it? """,
            """\n 
            You see a shotgun and a suit of armor.
            Should you pick it or ignore it? """]
            
    # Print a question list
    print(choice(question_listAUS))
    
    # Applyinng input prompt (Pick/Ignore)
    c1 = input(prompt = "(Pick/Ignore)> ")
    ans = 'incorrect'
  
    # Using .casefold() to lowercase
    ans =  ans.casefold()      
    
    # Looping until a player answer correctly   
    while(ans=='incorrect'):
        if c1.upper() in ('PICK','P'):
            print("""\n
            You made a right decision. Let's kill them all!
            You saved your friend too. He let you know that 
            a secret CODE is 123""")

            ans = 'correct'
            pick = "True"
            
         
        elif c1.upper() in ('IGNORE','I'):
            print("""\n
            Oh no, you missed your chance to get a new weapon. 
            You'd have pick it up! Your teammates died because your could 
            not protect them. Your action has a consequence!""")
            break
            fail()
            
            #room_astl()
            ans='correct'
            pick = "False"
           
        else:
            print("Wrong input! Enter pick or ignore?")
            c1=input(prompt = "(Pick/Ignore)> ")
     # Closing while function
    # Go to the next room        
    room_us()
    
# Welcome to the U.S
def room_us():
    print(f"""
            Well done, {player_name}! You are about to complete the mission.
            Now, you're in the U.S. 
            In this round, you need to answer Yes or No.""")
    
    # Importing random packages 
    import random 
    
    # Creating a question list that will be randomly selected 
    from random import choice 

    question_list = ["""\n
            You're about to destroy a large group of zombie 
            in New York and you'll be exhausted after that,
            do you want to grab some food? """,
        """\n
            You will run out of energy when fighting zombies in 
            Hawaii. Fortunately, you see a food store along the way. 
            Do you like to get some food? """, 
        """\n
            Pay attention that you are running out of enegery when 
            fighting. There's some food over there, do want to take it? """]
   
    # Printing a question list
    print(choice(question_list))

    # Answer the question above
    answer = input(prompt = "(Yes/No)> ")
    
    # Using .casefold() to lowercase
    answer = answer.casefold()  
    
    # Conditional statement 
    if answer in ('yes', 'y'):
        print(f"""
            That's a perfect choice! Enjoy the food and let's prepare
            for the next challenges.""")
        input(prompt = 'Press any key to continue>\n')
        Door()
    elif answer in ('no', 'n'): 
        print(f"""
            Fighting zombies will take a lot of effort, you should consider
            your choice!""")
        input(prompt = 'Press any key to try again>\n')
        room_us()
    else: 
        print("Invalid entry. Please try again.\n")
        fail()

  

# Welcome to the last room 
# Define variable code
code = 123

def Door():
    print(
        """
            You walked to the door. The rotary padlock contains three digits. 
            You enter a code.""")
    
# Looping until a player answer correctly    
    while True:
        try:
            option1 = int(input(prompt = "Digit one: "))
            break
        except:
            print("Digit one must be a number between 0-9:")

    while True:
        try:
            option2 = int(input(prompt = "Digit two: "))
            break
        except:
            print("Digit two must be a number between 0-9:")

    while True:
        try:
            option3 = int(input(prompt = "Digit three: "))
            break
        except:
            print("Digit three must be a number between 0-9:")
            
    # Decrypting the code       
    chosenCode = int(str(option1) + str(option2) + str(option3))
    print("")
    if chosenCode == code:
        print(
            """
            Congratulations, you have successfully rescued. 
            You are a superhero! Look forward to the next parts 
            in the near future.""")
    else:
        print("""You jiggle the padlock, but to no avail. 
        The code is incorrect. You died to the zomebies""")        
        return(0)


# Fail function 
def fail():
    print("You've failed, but thanks for playing!")
    input(prompt = '<Press any key to exit>\n')
    


room_jp()
# Out:
# What's your name? Khoa
#
#
#             Hi Khoa, welcome to Japan! You need to answer the
#             following question correctly to pass this room.
#
# Press any key to continue
#
#
#             You have arrived at Narita International Airport!
#
# <Press enter to continue>
#
# Press 1 to go to exit the airport.
# Press 2 to stay inside the airport.
# (1/2)> 1
#
#             Then you must answer the random question
#             before entering the country.
#
# "
#
#                   What is the traditional clothes of Japan?
#                   A) Kimono
#                   B) Cheongsam
# (A/B)> a
# That's correct! Please enjoy Japan and let's prepare
#                       for the next challenges.
# Press any key continue>
#
#
#             Now you're in Australia. You have a chance to pick up
#             some weapons and ammunition.
#             You will need to answer Pick or Ignore.
#
#
#             You see a shotgun and a suit of armor.
# ...

# %% [markdown]
# <br><hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" /><br>
#
# ~~~
#                                     ██████   ██████  ██      ██      ██ ███    ██  ██████
#                                     ██   ██ ██    ██ ██      ██      ██ ████   ██ ██
#                                     ██████  ██    ██ ██      ██      ██ ██ ██  ██ ██   ███
#                                     ██   ██ ██    ██ ██      ██      ██ ██  ██ ██ ██    ██
#                                     ██   ██  ██████  ███████ ███████ ██ ██   ████  ██████
#
#
#                                      █████  ██   ██ ███████  █████  ██████  ██
#                                     ██   ██ ██   ██ ██      ██   ██ ██   ██ ██
#                                     ███████ ███████ █████   ███████ ██   ██ ██
#                                     ██   ██ ██   ██ ██      ██   ██ ██   ██
#                                     ██   ██ ██   ██ ███████ ██   ██ ██████  ██
#
# ~~~
#
# <br><hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" /><br>
